# %% [markdown]
# ## package import

# %%
#import libraries
import cytoflow as flow

# mpl.use('TkAgg')
from itertools import product
import os
# %matplotlib inline
import matplotlib as mpl
from matplotlib.ticker import FuncFormatter
import scipy
from scipy import io
import seaborn as sns
import matplotlib.pyplot as plt
import math
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit
import sklearn
import sys
from scipy.special import factorial
import re
import statistics as stats
import itertools
from matplotlib.lines import Line2D
from pandas.api.types import CategoricalDtype
from scipy.stats import spearmanr

# %%
mpl.rcParams['font.sans-serif'] = "Helvetica Neue"
mpl.rcParams['font.family'] = "sans-serif"
plt.rcParams['figure.figsize'] = (10, 6)
mpl.rcParams['pdf.fonttype'] = 42 # make labels editable in pdf

mpl.rcParams['xtick.major.size'] = 20
mpl.rcParams['xtick.major.width'] = 1
mpl.rcParams['xtick.minor.size'] = 10
mpl.rcParams['xtick.minor.width'] = 1
mpl.rcParams['ytick.major.size'] = 20
mpl.rcParams['ytick.major.width'] = 1
mpl.rcParams['ytick.minor.size'] = 10
mpl.rcParams['ytick.minor.width'] = 1
mpl.rcParams['axes.linewidth'] = 1

sns.set_style("ticks")
sns.set_context("talk", font_scale = 0.5)
mpl.rc('figure', dpi = 160)

# %% [markdown]
# ## data import

# %%
# list the directories where you want to search for FCS files
ZE5rawdatapath = '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/'
dataDir = ['KRABHDAC_memory_comparison/']

separator_list = '_rep|_dox|_rec|_release' # modifly the next cell accordingly

# %%
#the following is copied directly from one of Connor's notebooks:
def find_tubes(fcsList, path, item):
    itempath = os.path.join(path, item)
    if os.path.isdir(itempath):
        for subitem in os.listdir(itempath):
            find_tubes(fcsList, itempath, subitem)
    elif '.fcs' in itempath:
        fcsList.append(itempath)
    return fcsList

fcsList = []

# find FCS files in the directories specified above
for path in dataDir:
    dataDirList = os.listdir(ZE5rawdatapath+path)
    for dirs in dataDirList:
        fcsList = find_tubes(fcsList, ZE5rawdatapath+path, dirs)

tubeList = []
for file in fcsList:
    file_elements = re.split(separator_list,file.split('/')[-1].split(' ')[1][:-4]) # remove well and .fcs, then split based on underscores
    target = file_elements[0]
    dox = int(file_elements[2])
    rec = float(file_elements[3])
    rel = int(file_elements[4])
    rep = int(file_elements[1])
    # rep = int(file_elements[-1].split('.')[0].split('p')[-1])
    tubeList.extend([flow.Tube(conditions = {'dox':dox,
                                             'rec':rec,
                                             'rel':rel,
                                        'target':target,
                                        'rep':rep,},
                          file = file,
                          conditions_list = ["dox", "rec", "rel", "target", "rep"])])

# %%
fcsList
# Out:
# ['/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/KRABHDAC_memory_comparison/B2 B9-HDAC4_rep2_dox0_rec0_release16.fcs',
#  '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/KRABHDAC_memory_comparison/A11 B9-HDAC4_rep2_dox1000_rec1_release16.fcs',
#  '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/KRABHDAC_memory_comparison/A12 B9-HDAC4_rep3_dox1000_rec1_release16.fcs',
#  '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/KRABHDAC_memory_comparison/A10 B9-HDAC4_rep1_dox1000_rec1_release16.fcs',
#  '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/KRABHDAC_memory_comparison/B1 B9-HDAC4_rep1_dox0_rec0_release16.fcs',
#  '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/KRABHDAC_memory_comparison/B3 B9-HDAC4_rep3_dox0_rec0_release16.fcs',
#  '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/KRABHDAC_memory_comparison/B5 B9-HDAC4_rep2_dox1000_rec5_release16.fcs',
#  '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/KRABHDAC_memory_comparison/B6 B9-HDAC4_rep3_dox1000_rec5_release16.fcs',
#  '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/KRABHDAC_memory_comparison/B4 B9-HDAC4_rep1_dox1000_rec5_release16.fcs']

# %%
#import tubes
op_0 = flow.ImportOp(conditions = {'dox':'int', 'rel':'int', 'rec':'float', 'target':'category', 'rep':'int'},
                tubes = tubeList, ignore_v=['FSC 488/10-A','FSC 488/10-H','FSC 488/10-W','SSC 488/10-A','SSC 488/10-W','SSC 488/10-H','mCitrine-A','mCitrine-W','mCitrine-H'])
ex_0 = op_0.apply()
# Out:
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel TLSW, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel TMSW, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel Event Info, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel FSC 488/10-H, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel FSC 488/10-A, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel FSC 488/10-W, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel SSC 488/10-H, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel SSC 488/10-A, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel SSC 488/10-W, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel mCitrine-H, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel mCitrine-A, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel mCitrine-W, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel mTurquoise-H, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel mTurquoise-A, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel mTurquoise-W, masking out 1 bits
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/cytoflow/operations/import_op.py:400: CytoflowWarning: The data range $PnR doesn't match the data bits $PnB for channel TIME, masking out 1 bits

# %% [markdown]
# ## set gating

# %%
#draw a polygon gate around live cells
op_1 = flow.PolygonOp(
    xchannel='FSC 488/10-A',
    vertices=[(3e8, 7e8),(0.5e9, 0.8e9),(1.1e9, 0.8e9),(1.35e9, 6e8),(1.1e9, 2e8),(2.5e8, 2e8)],
    ychannel='SSC 488/10-A',
    name='P1')

ex_1 = op_1.apply(ex_0)

# op_1.default_view(
#     yscale='linear',
#     xscale='linear',
#     huefacet='target').plot(ex_1, alpha = .01,
#                           xlim=(2e8, math.pow(2,31)), # originally 1e8 for lower end, 2^31 higher end
#                           ylim=(1e7, math.pow(2,31)), # originally 1e6 for lower end, 2^31 higher end
#                           height = 4,
#                           aspect = 1,)

P1_pos = len(ex_1.data[ex_1.data['P1']==True])
P1_neg = len(ex_1.data[ex_1.data['P1']==False])
P1_percent = str(round(100*P1_pos/(P1_pos + P1_neg), 1)) + '%'
print('Percent of events in P1 gate: %s' % P1_percent)
# Out:
# Percent of events in P1 gate: 92.1%

# %%
# set a polygon gate for single cells 'P2'
op_2 = flow.PolygonOp(name='P2',
                 xchannel='SSC 488/10-H',
                 ychannel='SSC 488/10-A',
                 vertices=[(1.2e8, 2.0e8),
                           (8.2e8, 1.55e9),
                           (10.5e8, 1.55e9),
                           (3.5e8, 2.0e8)])
ex_2 = op_2.apply(ex_1)

# view gate
# op_2.default_view(xscale = 'linear',
#                   yscale = 'linear',
#                   huefacet = 'dox',
#                   subset='(P1 == True)').plot(ex_2, alpha = 0.01, xlim=(0, 1.2e9), ylim=(0, 1.6e9))
#                 #   subset='(P1 == True)').plot(ex_2, alpha = 0.01, xlim=(0, 1.8e9), ylim=(0, 2.2e9))

# Check that most cells are singlets
P2_pos = len(ex_2.data[(ex_2.data['P2']==True) & (ex_2.data['P1']==True)])
P2_neg = len(ex_2.data[(ex_2.data['P2']==False) & (ex_2.data['P1']==True)])
P2_percent = str(round(100*P2_pos/(P2_pos + P2_neg), 1)) + '%'
print('Percent of P1 events in P2 gate: %s' % P2_percent)
# Out:
# Percent of P1 events in P2 gate: 99.0%

# %%
# set a polygon gate for single cells 'P2'
colors = ["#afafaf", "#dba468"]

op_3 = flow.ThresholdOp(name='mturq_pos',
                 channel='mTurquoise-A',
                 threshold=7.0e6)
ex_3 = op_3.apply(ex_2)

# view gate
op_3.default_view(scale = 'log',
                  huefacet = 'dox',
                  subset='(P1 == True)').plot(ex_3, alpha = 0.5, linewidth=0)# , palette=sns.color_palette(colors)) # , xlim=(0, 0.9e9), ylim=(0, 1.2e9))

# Check that most cells are singlets
P3mturq_pos = len(ex_3.data[(ex_3.data['mturq_pos']==True) & (ex_3.data['P2']==True) & (ex_3.data['P1']==True)])
P3mturq_neg = len(ex_3.data[(ex_3.data['mturq_pos']==False) & (ex_3.data['P2']==True) & (ex_3.data['P1']==True)])
P3_percent = str(round(100*P3mturq_pos/(P3mturq_pos + P3mturq_neg), 1)) + '%'
print('Percent of P1P2 events in P3 gate: %s' % P3_percent)
# plt.savefig(f'TFR003_Citrine_reactivated_memory_mChDistribution.pdf', dpi = 300)
# Out:
# Percent of P1P2 events in P3 gate: 90.7%

# %%
df = ex_3.data
df = df[(df['P2']==True)&(df['P1']==True)&(df['mturq_pos']==True)]
df.rename(columns={'mCitrine-A': 'Citrine-A', 'mCitrine-H': 'Citrine-H', 'mCitrine-W': 'Citrine-W'}, inplace = True)
# Out:
# /Users/tfuji/Documents/_mypyenvs/cytoflow-env/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dat_days = pd.DataFrame({'days': df['rec']+df['rel']})
df = df.join(dat_days)

# %%
targetList = sorted(df['target'].unique().tolist())
doxList = sorted(df['dox'].unique().tolist())
recList = sorted(df['rec'].unique().tolist())
relList = sorted(df['rel'].unique().tolist())
repList = sorted(df['rep'].unique().tolist())
dayList = sorted(df['days'].unique().tolist())
relList
# Out:
# [16]

# %%
# plot citrine for a given day
citrine_threshold = 8.8e6
# citrine_threshold = 16.0e6
# Set your custom color palette
colors = ["#bfbfbf","#dba468"]
sns.set_palette(sns.color_palette(colors))

data = df # [(df['rep'] == 1)]
f = sns.FacetGrid(
    data = data,
    row='rec',
    row_order=recList,
    hue='rep',
    hue_order=repList,
    sharey = False,
    height = 1,
    aspect = 2.4,
    margin_titles = False,
)

for ax in f.axes.flat: # zip(f.axes.flat, repList): # # ax, title in zip(f.axes.flat, targetList):
    ax.set_xlabel('Citrine-A', size = 10)
    ax.set_ylabel('density', size = 10)
    ax.set_xlim([1e5, 10e8])
    # ax.set_ylim([0, 0.2])
    ax.tick_params(axis='both',which='both',width=1, length=5)
    ax.spines['bottom'].set_linewidth(1)
    ax.spines['left'].set_linewidth(1)

# f.map(sns.kdeplot, 'Citrine-A', hue='rep', og_scale = True, bw_adjust = 0.6, fill=True, alpha=0.1, linewidth=1)
f.map_dataframe(sns.kdeplot, x='Citrine-A', common_norm=False, multiple='layer',
                log_scale=True, bw_adjust=0.6, fill=True, alpha=0.1, linewidth=1, palette=sns.color_palette(colors))
f.map(plt.axvline, x=citrine_threshold, ls=':', color='#333333', linewidth=1)

f.set_titles('')
# f.set(yticks = [], ylabel = '')
# f.despine(left=True)
plt.tight_layout()
# plt.savefig(f'TFR001_Citrine_timecourse.pdf', dpi = 300)

# %%
# plot citrine for a given day
citrine_threshold = 8.8e6
# citrine_threshold = 16.0e6
# Set your custom color palette
colors = ["#bfbfbf","#dba468"]
sns.set_palette(sns.color_palette(colors))

data = df[(df['rep'] == 1)]
f = sns.FacetGrid(
    data = data,
    row='rec',
    row_order=recList,
    hue='dox',
    hue_order=doxList,
    sharey = False,
    height = 1,
    aspect = 2.4,
    margin_titles = False,
)

for ax in f.axes.flat: # zip(f.axes.flat, repList): # # ax, title in zip(f.axes.flat, targetList):
    ax.set_xlabel('mTurquoise-A', size = 10)
    ax.set_ylabel('density', size = 10)
    ax.set_xlim([1e5, 10e8])
    # ax.set_ylim([0, 0.2])
    ax.tick_params(axis='both',which='both',width=1, length=5)
    ax.spines['bottom'].set_linewidth(1)
    ax.spines['left'].set_linewidth(1)

# f.map(sns.kdeplot, 'mTurquoise-A', hue='rep', og_scale = True, bw_adjust = 0.6, fill=True, alpha=0.1, linewidth=1)
f.map_dataframe(sns.kdeplot, x='mTurquoise-A', common_norm=False, multiple='layer',
                log_scale=True, bw_adjust=0.6, fill=True, alpha=0.1, linewidth=1, palette=sns.color_palette(colors))
# f.map(plt.axvline, x=citrine_threshold, ls=':', color='#333333', linewidth=1)

f.set_titles('')
# f.set(yticks = [], ylabel = '')
# f.despine(left=True)
plt.tight_layout()
# plt.savefig(f'TFR001_Citrine_timecourse.pdf', dpi = 300)

# %% [markdown]
# ## calculate silenced fraction

# %%
sil_fracs = np.empty((len(targetList), len(recList), len(repList))) * np.nan

for lb, label in enumerate(targetList):
    dataA = df[df['target'] == label]
    for rc, rec in enumerate(recList):
        dataC = dataA[dataA['rec'] == rec]
        for rp, rep in enumerate(repList):
            data = dataC[dataC['rep'] == rep]
            all = len(data)
            if all > 0:
                citrine_off = len(data[(data["Citrine-A"] < citrine_threshold)])
                sil_fracs[lb, rc, rp] = citrine_off/all

# %%
# load KRAB memory

ZE5rawdatapath_KRAB = '/Users/tfuji/Library/CloudStorage/GoogleDrive-tfuji@stanford.edu/My Drive/flow_analysis/rawdata_KRAB/'
sil_fracs_KRAB = np.load(ZE5rawdatapath_KRAB+'KRAB_A6vsB9_OFFfracDay16_tgt-dox-rec-rep.npy')

# sil_fracs_avg_KRAB = np.nanmean(sil_fracs_KRAB,axis=3)

# %%
# Out:
# array([[0.00065186, 0.00190549, 0.00060928],
#        [0.20276008, 0.20178544, 0.18917213],
#        [0.37417143, 0.40658641, 0.37975774]])

# %%
# Create the figure and axis
# fig, ax = plt.subplots(figsize=(3, 3))
colors = ["#bfbfbf","#dba468","#dba468"]
labels = ['KRAB','HDAC4']

for ii in range(2):
    fig, ax = plt.subplots(figsize=(3, 2.5))
    if ii == 0:
        dat = np.sqrt(sil_fracs_KRAB[3,:,:,:].reshape((4,3))[1:,:])
        offset = 0
    elif ii == 1:
        dat = np.sqrt(sil_fracs.reshape((3,3)))# day x rep
        offset = 0

    means = np.mean(dat, axis=1)
    # X positions for the bars
    bar_positions = np.arange(len(means)) + offset

    # Plot the bars for the mean values
    ax.bar(bar_positions, means, color=colors, width=0.8)

    # Plot individual data points
    for i in range(dat.shape[0]):
        ax.plot(np.full(dat.shape[1], i)+offset+[-0.2,0,0.2], dat[i, :], 'o', color='white',
                markeredgecolor='k', markeredgewidth=1,markersize=5)
    # Add labels and title

    plt.xlim(-0.75, 2.75)
    plt.ylim(0.0, 0.8)

    ax.xaxis.set_tick_params(width=1, length=5)
    ax.yaxis.set_tick_params(width=1, length=5)
    ax.spines[:].set_linewidth(1)
    ax.spines[['top','right']].set_linewidth(0)
    plt.ylabel('memory fraction')
    plt.tight_layout()

    ax.set_xticks([0,1,2])
    ax.set_xticklabels(['0', '1','5'])
    # ax.set_ylabel('Values')
    ax.set_title('memory at day 16 after dox removal')

    # Show plot
    plt.show()
    # fig.savefig(labels[ii]+'_memory16day_recD0-1-5.pdf', dpi = 300)

# %%
dat.shape
# Out:
# (3, 3)

# %%
# Create the figure and axis
# fig, ax = plt.subplots(figsize=(3, 3))
colors = ["#bfbfbf","#dba468","#dba468"]
labels = ['KRAB','HDAC4']

for ii in range(2):
    fig, ax = plt.subplots(figsize=(2.5, 3))
    if ii == 0:
        dat = np.sqrt(sil_fracs_KRAB[3,:,:,:].reshape((4,3))[1:,:])
        offset = 0
    elif ii == 1:
        dat = np.sqrt(sil_fracs.reshape((3,3)))# day x rep
        offset = 0

    means = np.mean(dat[0:-1,:], axis=1)
    # X positions for the bars
    bar_positions = np.arange(len(means)) + offset

    # Plot the bars for the mean values
    ax.bar(bar_positions, means, color=colors, width=0.8)

    # Plot individual data points
    for i in range(dat.shape[0]-1):
        ax.plot(np.full(dat.shape[1], i)+offset+[-0.2,0,0.2], dat[i, :], 'o', color='white',
                markeredgecolor='k', markeredgewidth=1,markersize=5)
    # Add labels and title

    plt.xlim(-0.75, 1.75)
    plt.ylim(0.0, 1.0)

    ax.xaxis.set_tick_params(width=1, length=5)
    ax.yaxis.set_tick_params(width=1, length=5)
    ax.spines[:].set_linewidth(1)
    ax.spines[['top','right']].set_linewidth(0)
    plt.ylabel('memory fraction')
    plt.tight_layout()

    ax.set_xticks([0,1])
    ax.set_xticklabels(['0', '1'])
    # ax.set_ylabel('Values')
    # ax.set_title('memory at day 16 after dox removal')

    # Show plot
    plt.show()
    fig.savefig(labels[ii]+'_memory16day_recD0-1.pdf', dpi = 300)

# %%
# Create the figure and axis
# fig, ax = plt.subplots(figsize=(3, 3))
colors = ["#bfbfbf","#dba468","#dba468"]
labels = ['KRAB','HDAC4']

for ii in range(2):
    fig, ax = plt.subplots(figsize=(2.5, 3))
    if ii == 0:
        dat = np.sqrt(sil_fracs_KRAB[3,:,:,:].reshape((4,3))[1:,:])
        offset = 0
    elif ii == 1:
        dat = np.sqrt(sil_fracs.reshape((3,3)))# day x rep
        offset = 0

    means = np.mean(dat[[0,2],:], axis=1)
    # X positions for the bars
    bar_positions = np.arange(len(means)) + offset

    # Plot the bars for the mean values
    ax.bar(bar_positions, means, color=colors, width=0.8)

    # Plot individual data points
    for i in [0,2]:
        ax.plot(np.full(dat.shape[1], i/2)+offset+[-0.2,0,0.2], dat[i, :], 'o', color='white',
                markeredgecolor='k', markeredgewidth=1,markersize=5)
    # Add labels and title

    plt.xlim(-0.75, 1.75)
    plt.ylim(0.0, 1.0)

    ax.xaxis.set_tick_params(width=1, length=5)
    ax.yaxis.set_tick_params(width=1, length=5)
    ax.spines[:].set_linewidth(1)
    ax.spines[['top','right']].set_linewidth(0)
    plt.ylabel('memory fraction')
    plt.tight_layout()

    ax.set_xticks([0,1])
    ax.set_xticklabels(['0', '5'])
    # ax.set_ylabel('Values')
    # ax.set_title('memory at day 16 after dox removal')

    # Show plot
    plt.show()
    fig.savefig(labels[ii]+'_memory16day_recD0-5.pdf', dpi = 300)

# %% [markdown]
# ## silenced fraction by RNAFISH

# %%
avgrna = io.loadmat(ZE5rawdatapath+'davgrna_B9.mat')

# %%
labels = ['KRAB','HDAC4']
colors = ["#bfbfbf","#dba468","#dba468"]

for kk in range(2):
    condition_toplot = [labels[kk]+'-nodox',labels[kk]+'-1day']
    dnames = avgrna['davgrna']['dname'][0][0][0]
    silfrac_rna = avgrna['davgrna']['silfrac'][0][0]

    dat = np.empty((1, 2))
    for ii in range(2):
        dat = np.append(dat,silfrac_rna[dnames == condition_toplot[ii]].T,axis=0)
    dat = dat[1:,:]

    fig, ax = plt.subplots(figsize=(2.5, 3))
    means = np.mean(dat, axis=1)
    # X positions for the bars
    bar_positions = np.arange(len(means))

    # Plot the bars for the mean values
    ax.bar(bar_positions, means, color=colors, width=0.8)

    # Plot individual data points
    for i in [0,1]:
        ax.plot(np.full(dat.shape[1], i)+[-0.2,0.2], dat[i, :], 'o', color='white',
                markeredgecolor='k', markeredgewidth=1,markersize=5)
    # Add labels and title

    plt.xlim(-0.75, 1.75)
    plt.ylim(0.0, 1.0)

    ax.xaxis.set_tick_params(width=1, length=5)
    ax.yaxis.set_tick_params(width=1, length=5)
    ax.spines[:].set_linewidth(1)
    ax.spines[['top','right']].set_linewidth(0)
    plt.ylabel('silenced fraction')
    plt.tight_layout()

    ax.set_xticks([0,1])
    ax.set_xticklabels(['0', '1'])

    # Show plot
    plt.show()
    # fig.savefig(labels[kk]+'_silenced_1day_B9.pdf', dpi = 300)

# %%
labels = ['KRAB','HDAC4']
colors = ["#bfbfbf","#dba468","#dba468"]

for kk in range(2):
    condition_toplot = [labels[kk]+'-nodox',labels[kk]+'-5days']
    dnames = avgrna['davgrna']['dname'][0][0][0]
    silfrac_rna = avgrna['davgrna']['silfrac'][0][0]

    dat = np.empty((1, 2))
    for ii in range(2):
        dat = np.append(dat,silfrac_rna[dnames == condition_toplot[ii]].T,axis=0)
    dat = dat[1:,:]

    fig, ax = plt.subplots(figsize=(2.5, 3))
    means = np.mean(dat, axis=1)
    # X positions for the bars
    bar_positions = np.arange(len(means))

    # Plot the bars for the mean values
    ax.bar(bar_positions, means, color=colors, width=0.8)

    # Plot individual data points
    for i in [0,1]:
        ax.plot(np.full(dat.shape[1], i)+[-0.2,0.2], dat[i, :], 'o', color='white',
                markeredgecolor='k', markeredgewidth=1,markersize=5)
    # Add labels and title
    plt.xlim(-0.75, 1.75)
    plt.ylim(0.0, 1.0)

    ax.xaxis.set_tick_params(width=1, length=5)
    ax.yaxis.set_tick_params(width=1, length=5)
    ax.spines[:].set_linewidth(1)
    ax.spines[['top','right']].set_linewidth(0)
    plt.ylabel('silenced fraction')
    plt.tight_layout()

    ax.set_xticks([0,1])
    ax.set_xticklabels(['0', '5'])

    # Show plot
    plt.show()
    fig.savefig(labels[kk]+'_silenced_5days_B9.pdf', dpi = 300)

# %% [markdown]
# ## scatter plot with fitting curves

# %%
def linearfunc(x, a):
    return a*x

def quadraticfunc(x, a):
    return a*x**2

linfitcolor = ['#aaaaaaaa','#00aaff']
ylabels = ['Silenced fraction in\ndouble integrant clone','√Silenced fraction in\ndouble integrant clone']

fig = plt.figure(figsize = (5.5, 3))

for ii in range(2):
    if ii == 0:
        ydata = B9avg
        yerrdata = B9std
    elif ii == 1:
        ydata = B9sqavg
        yerrdata = B9sqstd

    ax = plt.subplot(1,2,ii+1)
    xdata = np.linspace(0, 0.9, 50)
    popt, pcov, infordict, mesg, ier = scipy.optimize.curve_fit(linearfunc, A6avg, ydata, full_output=True)
    plt.plot(xdata, linearfunc(xdata, *popt),'-',color=linfitcolor[ii],linewidth=1, zorder=1)
    # text = 'error = %0.4f' % np.sum(infordict['fvec']**2) # residual sum of squares
    if ii == 1:
        text = 'slope = %0.2f' % popt[0]
        ax.text(0.05, 0.9, text, transform=ax.transAxes, ha='left', va='center', size=8,color=linfitcolor[ii])
        text = 'Pearson\'s r = %0.2f' % scipy.stats.pearsonr(A6avg, ydata)[0]
        ax.text(0.05, 0.8, text, transform=ax.transAxes, ha='left', va='center', size=8,color=linfitcolor[ii])

    # print(sklearn.metrics.r2_score(ydata, linearfunc(A6avg, *popt))) # R2
    print(np.sum(infordict['fvec']**2)) # same as     print(np.sum((ydata - linearfunc(A6avg, *popt))**2))
    print(popt)

    if ii == 0:
        popt, pcov, infordict, mesg, ier = scipy.optimize.curve_fit(quadraticfunc, A6avg, ydata, full_output=True)
        plt.plot(xdata, quadraticfunc(xdata, *popt),'-',color='#00aaff',linewidth=1, zorder=2)
        # print(sklearn.metrics.r2_score(ydata, quadraticfunc(A6avg, *popt)))
        print(np.sum(infordict['fvec']**2)) # same as         print(np.sum((ydata - quadraticfunc(A6avg, *popt))**2))
        print(popt)
        # text = 'error = %0.4f' % np.sum(infordict['fvec']**2) # f"{round(100 * np.mean(cto_fracs[labelDict[title], :, day_index]), 1)}%"
        # ax.text(0.1, 0.7, text, transform=ax.transAxes, ha='left', va='center', size=8,color='#00aaff')

    plt.scatter(A6avg, ydata, s=50, zorder=3,edgecolors='#ee9900',facecolors='none', lw=1)
    plt.errorbar(A6avg, ydata, xerr=A6std, fmt='none', lw=1, color='#ee9900', zorder=4)
    plt.errorbar(A6avg, ydata, yerr=yerrdata, fmt='none', lw=1, color='#ee9900', zorder=4)

    plt.xlabel('Silenced fraction in\nsingle integrant clone')
    plt.ylabel(ylabels[ii])

plt.tight_layout()
plt.show()
fig.savefig('memory_single-double_comparison.pdf', dpi = 300)
# Out:
# 0.020551411168366483
# [0.37875694]
# 0.0020569732006985365
# [0.58543013]
# 0.007846805843553874
# [0.7426388]
